# %% [markdown]
# ## Uncovering Trends Between Hyperparameters and Performance Metrics for Binary Classification using Feedforward Neural Networks
#
# How well does evolutionary algorithms evolve multilayer perceptrons for my Breast Cancer binary classification task to find a Pareto optimal set of non-dominated solutions based on multiple objectives?

# %%
import pickle
from pathlib import Path
import sys
import pandas as pd
import json


# Add your evolutionary-ml root folder to the Python path
sys.path.append(str(Path("../workflow/netArchSearch")))

# Now you can import directly
from solution import Solution

# %%
# path to .dat files
solutions_path = '../outputs/solutions.dat'
evo_final_pareto_path = '../outputs/evo_final_pareto.dat'
evo_final_pareto_validated_path = '../outputs/evo_final_pareto_validated.dat'
#pareto_historical_validated_path = '../outputs/pareto_historical_validated.dat'

# open and load the pickle file
with open(solutions_path, 'rb') as f:
    solutions = pickle.load(f)

with open(evo_final_pareto_path, 'rb') as f:
    evo_final_pareto_set = pickle.load(f)

with open(evo_final_pareto_validated_path, 'rb') as f:
    evo_final_pareto_validated_set = pickle.load(f)

# with open(pareto_historical_validated_path, 'rb') as f:
#     pareto_historical_validated_set = pickle.load(f)
# Out:
# 1125

# %%
# ensure that both the files save properly (information should be the same0)
len(solutions), len(evo_final_pareto_set)

# compare keys (objective tuples)
print("Common:", len(set(solutions.keys()) & set(evo_final_pareto_set.keys())))
print("New in final:", len(set(evo_final_pareto_set.keys()) - set(solutions.keys())))
# Out:
# Common: 1125
# New in final: 0

# %%
# load jsonl file of all solutions from evo process
jsonl_file = '../outputs/all_solutions.jsonl'
data = []
with open(jsonl_file, 'r') as f:
    for line in f:
        line = line.strip()
        if line:  # skip empty lines
            data.append(json.loads(line))

# flatten nested dictionaries and rename columns
df = pd.json_normalize(data, sep='_')  # hyperparams_loss_function, metrics_accuracy, etc.
df = df.rename(
    columns={col: col.replace('hyperparams_', 'hyp_').replace('metrics_', 'obj_') for col in df.columns}
)

# %%
# look at the entire simulated population in evolution
df
# Out:
#               hyp_loss_function  hyp_hidden_layer_count  \
# 0     binary_focal_crossentropy                      16
# 1     binary_focal_crossentropy                      11
# 2             cosine_similarity                      10
# 3     binary_focal_crossentropy                       2
# 4           binary_crossentropy                       3
# ...                         ...                     ...
# 4306        binary_crossentropy                       2
# 4307  binary_focal_crossentropy                       3
# 4308  binary_focal_crossentropy                       2
# 4309  binary_focal_crossentropy                       1
# 4310  binary_focal_crossentropy                       4
#
#                              hyp_units_per_hidden_layer  \
# 0     [115, 86, 84, 110, 80, 23, 20, 30, 44, 40, 94,...
# 1         [63, 17, 100, 36, 17, 49, 36, 85, 53, 59, 38]
# 2          [118, 126, 83, 38, 67, 96, 68, 100, 103, 53]
# 3                                             [45, 102]
# 4                                          [32, 31, 53]
# ...                                                 ...
# 4306                                            [45, 3]
# 4307                                      [32, 31, 116]
# 4308                                          [45, 112]
# 4309                                               [45]
# 4310                                 [82, 101, 12, 100]
#
#                         hyp_activation_per_hidden_layer hyp_optimizer  \
# 0     [tanh, relu, sigmoid, relu, tanh, sigmoid, sig...           sgd
# 1     [relu, sigmoid, relu, relu, relu, relu, sigmoi...       rmsprop
# 2     [tanh, tanh, tanh, tanh, tanh, tanh, tanh, sig...       rmsprop
# 3                                          [relu, relu]       rmsprop
# 4                                    [relu, relu, relu]       rmsprop
# ...                                                 ...           ...
# 4306                                       [relu, tanh]       rmsprop
# 4307                                 [relu, relu, relu]       rmsprop
# 4308                                       [relu, tanh]           sgd
# 4309                                             [relu]           sgd
# 4310                        [tanh, sigmoid, tanh, tanh]           sgd
#
#       hyp_epochs  hyp_batch_size  hyp_feature_count  hyp_class_count  \
# 0             18              64                 30                2
# 1              8              16                 30                2
# 2             17              16                 30                2
# 3             20             128                 30                2
# 4              7             128                 30                2
# ...          ...             ...                ...              ...
# 4306           8             128                 30                2
# 4307           7             128                 30                2
# 4308          20             128                 30                2
# 4309          20             128                 30                2
# 4310          13              32                 30                2
#
#       obj_total_layers  ...  obj_training_time  obj_loss  obj_accuracy  \
# 0                   18  ...           0.507657  0.160724      0.666667
# 1                   13  ...           0.721492  0.013756      0.991228
# 2                   12  ...           0.829604 -0.666667      0.666667
# 3                    4  ...           0.481059  0.015444      0.982456
# 4                    5  ...           0.300834  0.253914      0.921053
# ...                ...  ...                ...       ...           ...
# 4306                 4  ...           0.340876  0.423036      0.938596
# 4307                 5  ...           0.381944  0.041907      0.956140
# 4308                 4  ...           0.400073  0.066312      0.885965
# 4309                 3  ...           0.390022  0.065872      0.938596
# 4310                 6  ...           0.367889  0.115110      0.868421
#
#       obj_false_positive_rate  obj_false_negative_rate  \
# 0                    1.000000                 0.000000
# 1                    0.000000                 0.013158
# 2                    1.000000                 0.000000
# 3                    0.026316                 0.013158
# 4                    0.157895                 0.039474
# ...                       ...                      ...
# 4306                 0.131579                 0.026316
# 4307                 0.026316                 0.052632
# 4308                 0.236842                 0.052632
# 4309                 0.105263                 0.039474
# 4310                 0.315789                 0.039474
#
#       obj_true_positive_rate  obj_true_negative_rate    obj_f1  obj_precision  \
# 0                   1.000000                0.000000  0.800000       0.666667
# 1                   0.986842                1.000000  0.000000       1.000000
# 2                   1.000000                0.000000  0.800000       0.666667
# 3                   0.986842                0.973684  0.051265       0.986842
# 4                   0.960526                0.842105  0.269704       0.924051
# ...                      ...                     ...       ...            ...
# 4306                0.973684                0.868421  0.230745       0.936709
# 4307                0.947368                0.973684  0.051264       0.986301
# 4308                0.947368                0.763158  0.374026       0.888889
# 4309                0.960526                0.894737  0.189487       0.948052
# 4310                0.960526                0.684211  0.461782       0.858824
#
#        obj_auc
# 0     0.653566
# 1     0.998615
# 2     0.965028
# 3     0.998615
# 4     0.983726
# ...        ...
# 4306  0.986150
# 4307  0.989612
# 4308  0.967798
# 4309  0.976108
# 4310  0.952216
#
# [4311 rows x 21 columns]

# %%
# look at only the objective functions
objectives = [col for col in df.columns if 'obj' in col]
display(df[objectives])
# Out:
#       obj_total_layers  obj_total_nodes  obj_training_time  obj_loss  \
# 0                   18             1115           0.507657  0.160724
# 1                   13              585           0.721492  0.013756
# 2                   12              884           0.829604 -0.666667
# 3                    4              179           0.481059  0.015444
# 4                    5              148           0.300834  0.253914
# ...                ...              ...                ...       ...
# 4306                 4               80           0.340876  0.423036
# 4307                 5              211           0.381944  0.041907
# 4308                 4              189           0.400073  0.066312
# 4309                 3               77           0.390022  0.065872
# 4310                 6              327           0.367889  0.115110
#
#       obj_accuracy  obj_false_positive_rate  obj_false_negative_rate  \
# 0         0.666667                 1.000000                 0.000000
# 1         0.991228                 0.000000                 0.013158
# 2         0.666667                 1.000000                 0.000000
# 3         0.982456                 0.026316                 0.013158
# 4         0.921053                 0.157895                 0.039474
# ...            ...                      ...                      ...
# 4306      0.938596                 0.131579                 0.026316
# 4307      0.956140                 0.026316                 0.052632
# 4308      0.885965                 0.236842                 0.052632
# 4309      0.938596                 0.105263                 0.039474
# 4310      0.868421                 0.315789                 0.039474
#
#       obj_true_positive_rate  obj_true_negative_rate    obj_f1  obj_precision  \
# 0                   1.000000                0.000000  0.800000       0.666667
# 1                   0.986842                1.000000  0.000000       1.000000
# 2                   1.000000                0.000000  0.800000       0.666667
# 3                   0.986842                0.973684  0.051265       0.986842
# 4                   0.960526                0.842105  0.269704       0.924051
# ...                      ...                     ...       ...            ...
# 4306                0.973684                0.868421  0.230745       0.936709
# 4307                0.947368                0.973684  0.051264       0.986301
# 4308                0.947368                0.763158  0.374026       0.888889
# 4309                0.960526                0.894737  0.189487       0.948052
# 4310                0.960526                0.684211  0.461782       0.858824
#
#        obj_auc
# 0     0.653566
# 1     0.998615
# 2     0.965028
# 3     0.998615
# 4     0.983726
# ...        ...
# 4306  0.986150
# 4307  0.989612
# 4308  0.967798
# 4309  0.976108
# 4310  0.952216
#
# [4311 rows x 12 columns]

# %%
def dominates(p, q, obj_cols):
    """
    Returns True if row p dominates row q based on objectives in obj_cols.
    For minimization: p dominates q if p is better or equal in all objectives 
    and strictly better in at least one.
    """
    pscores = p[obj_cols].values
    qscores = q[obj_cols].values
    
    # p dominates q if p <= q in all objectives and p < q in at least one
    all_better_or_equal = all(pscores <= qscores)
    at_least_one_better = any(pscores < qscores)
    
    return all_better_or_equal and at_least_one_better

def remove_dominated(df, obj_cols):
    """
    Removes dominated rows from df based on objectives.
    """
    non_dominated_indices = set(df.index)

    for i, p in df.iterrows():
        if i in non_dominated_indices:
            # Only check against other non-dominated solutions
            dominated = {j for j in non_dominated_indices 
                        if i != j and dominates(p, df.loc[j], obj_cols)}
            non_dominated_indices -= dominated

    return df.loc[sorted(non_dominated_indices)]

# %%
# create the pareto set from the historical solutions
pareto_historical_set = remove_dominated(df, objectives)
pareto_historical_set
# Out:
#               hyp_loss_function  hyp_hidden_layer_count  \
# 1     binary_focal_crossentropy                      11
# 4           binary_crossentropy                       3
# 14            cosine_similarity                       2
# 17    binary_focal_crossentropy                      11
# 21    binary_focal_crossentropy                      11
# ...                         ...                     ...
# 4304          cosine_similarity                       1
# 4307  binary_focal_crossentropy                       3
# 4308  binary_focal_crossentropy                       2
# 4309  binary_focal_crossentropy                       1
# 4310  binary_focal_crossentropy                       4
#
#                          hyp_units_per_hidden_layer  \
# 1     [63, 17, 100, 36, 17, 49, 36, 85, 53, 59, 38]
# 4                                      [32, 31, 53]
# 14                                        [45, 102]
# 17    [63, 17, 100, 36, 17, 49, 36, 85, 53, 96, 38]
# 21    [63, 17, 100, 36, 17, 49, 36, 85, 53, 59, 38]
# ...                                             ...
# 4304                                           [45]
# 4307                                  [32, 31, 116]
# 4308                                      [45, 112]
# 4309                                           [45]
# 4310                             [82, 101, 12, 100]
#
#                         hyp_activation_per_hidden_layer hyp_optimizer  \
# 1     [relu, sigmoid, relu, relu, relu, relu, sigmoi...       rmsprop
# 4                                    [relu, relu, relu]       rmsprop
# 14                                         [relu, relu]       rmsprop
# 17    [relu, sigmoid, relu, relu, relu, relu, sigmoi...       rmsprop
# 21    [relu, sigmoid, relu, relu, relu, relu, sigmoi...       rmsprop
# ...                                                 ...           ...
# 4304                                             [relu]       rmsprop
# 4307                                 [relu, relu, relu]       rmsprop
# 4308                                       [relu, tanh]           sgd
# 4309                                             [relu]           sgd
# 4310                        [tanh, sigmoid, tanh, tanh]           sgd
#
#       hyp_epochs  hyp_batch_size  hyp_feature_count  hyp_class_count  \
# 1              8              16                 30                2
# 4              7             128                 30                2
# 14            20             128                 30                2
# 17             8              16                 30                2
# 21             8              16                 30                2
# ...          ...             ...                ...              ...
# 4304           8              16                 30                2
# 4307           7             128                 30                2
# 4308          20             128                 30                2
# 4309          20             128                 30                2
# 4310          13              32                 30                2
#
#       obj_total_layers  ...  obj_training_time  obj_loss  obj_accuracy  \
# 1                   13  ...           0.721492  0.013756      0.991228
# 4                    5  ...           0.300834  0.253914      0.921053
# 14                   4  ...           0.452408 -0.666667      0.280702
# 17                  13  ...           0.684649  0.019434      0.973684
# 21                  13  ...           0.686648  0.023276      0.956140
# ...                ...  ...                ...       ...           ...
# 4304                 3  ...           0.442016 -0.666667      0.754386
# 4307                 5  ...           0.381944  0.041907      0.956140
# 4308                 4  ...           0.400073  0.066312      0.885965
# 4309                 3  ...           0.390022  0.065872      0.938596
# 4310                 6  ...           0.367889  0.115110      0.868421
#
#       obj_false_positive_rate  obj_false_negative_rate  \
# 1                    0.000000                 0.013158
# 4                    0.157895                 0.039474
# 14                   0.315789                 0.921053
# 17                   0.078947                 0.000000
# 21                   0.131579                 0.000000
# ...                       ...                      ...
# 4304                 0.684211                 0.026316
# 4307                 0.026316                 0.052632
# 4308                 0.236842                 0.052632
# 4309                 0.105263                 0.039474
# 4310                 0.315789                 0.039474
#
#       obj_true_positive_rate  obj_true_negative_rate    obj_f1  obj_precision  \
# 1                   0.986842                1.000000  0.000000       1.000000
# 4                   0.960526                0.842105  0.269704       0.924051
# 14                  0.078947                0.684211  0.324324       0.333333
# 17                  1.000000                0.921053  0.145920       0.962025
# 21                  1.000000                0.868421  0.230793       0.938272
# ...                      ...                     ...       ...            ...
# 4304                0.973684                0.315789  0.711013       0.740000
# 4307                0.947368                0.973684  0.051264       0.986301
# 4308                0.947368                0.763158  0.374026       0.888889
# 4309                0.960526                0.894737  0.189487       0.948052
# 4310                0.960526                0.684211  0.461782       0.858824
#
#        obj_auc
# 1     0.998615
# 4     0.983726
# 14    0.257271
# 17    0.998269
# 21    0.998615
# ...        ...
# 4304  0.809211
# 4307  0.989612
# 4308  0.967798
# 4309  0.976108
# 4310  0.952216
#
# [2288 rows x 21 columns]

# %%
# calculate what is the search space
df[df.obj_accuracy == df.obj_accuracy.max()]
# Out:
#               hyp_loss_function  hyp_hidden_layer_count  \
# 260   binary_focal_crossentropy                       1
# 262   binary_focal_crossentropy                       1
# 357         binary_crossentropy                       3
# 483   binary_focal_crossentropy                       1
# 634   binary_focal_crossentropy                       1
# 1026  binary_focal_crossentropy                      10
# 1414  binary_focal_crossentropy                       1
# 1517  binary_focal_crossentropy                       2
# 1556  binary_focal_crossentropy                       1
# 1654        binary_crossentropy                       2
# 2039  binary_focal_crossentropy                       2
# 2455        binary_crossentropy                       4
# 2680  binary_focal_crossentropy                       1
# 2924  binary_focal_crossentropy                       2
#
#                       hyp_units_per_hidden_layer  \
# 260                                         [45]
# 262                                         [45]
# 357                                 [32, 40, 53]
# 483                                         [45]
# 634                                         [45]
# 1026  [63, 17, 100, 36, 17, 49, 36, 127, 59, 38]
# 1414                                        [45]
# 1517                                    [45, 12]
# 1556                                        [45]
# 1654                                   [45, 605]
# 2039                                    [45, 38]
# 2455                           [32, 31, 53, 116]
# 2680                                        [45]
# 2924                                    [45, 68]
#
#                         hyp_activation_per_hidden_layer hyp_optimizer  \
# 260                                              [relu]       rmsprop
# 262                                              [relu]       rmsprop
# 357                                  [relu, relu, relu]       rmsprop
# 483                                              [relu]       rmsprop
# 634                                              [relu]       rmsprop
# 1026  [relu, sigmoid, relu, relu, relu, relu, sigmoi...          adam
# 1414                                             [relu]       rmsprop
# 1517                                       [relu, relu]       rmsprop
# 1556                                             [relu]       rmsprop
# 1654                                       [relu, relu]       rmsprop
# 2039                                       [relu, tanh]       rmsprop
# 2455                           [relu, relu, relu, relu]       rmsprop
# 2680                                             [relu]       rmsprop
# 2924                                       [relu, tanh]       rmsprop
#
#       hyp_epochs  hyp_batch_size  hyp_feature_count  hyp_class_count  \
# 260           20             128                 30                2
# 262           20             128                 30                2
# 357           13             128                 30                2
# 483           20             128                 30                2
# 634           20             128                 30                2
# 1026           8              16                 30                2
# 1414          20             128                 30                2
# 1517          12              16                 30                2
# 1556          20             128                 30                2
# 1654          12              64                 30                2
# 2039          11              16                 30                2
# 2455          14              16                 30                2
# 2680          20             128                 30                2
# 2924           6              32                 30                2
#
#       obj_total_layers  ...  obj_training_time  obj_loss  obj_accuracy  \
# 260                  3  ...           0.467447  0.020645           1.0
# 262                  3  ...           0.467447  0.020645           1.0
# 357                  5  ...           0.417824  0.077094           1.0
# 483                  3  ...           0.467447  0.020645           1.0
# 634                  3  ...           0.467447  0.020645           1.0
# 1026                12  ...           1.063067  0.008093           1.0
# 1414                 3  ...           0.467447  0.020645           1.0
# 1517                 4  ...           0.494472  0.008819           1.0
# 1556                 3  ...           0.467447  0.020645           1.0
# 1654                 4  ...           0.413738  0.043737           1.0
# 2039                 4  ...           0.476511  0.010988           1.0
# 2455                 6  ...           0.575553  0.015680           1.0
# 2680                 3  ...           0.467447  0.020645           1.0
# 2924                 4  ...           0.364561  0.011095           1.0
#
#       obj_false_positive_rate  obj_false_negative_rate  \
# 260                       0.0                      0.0
# 262                       0.0                      0.0
# 357                       0.0                      0.0
# 483                       0.0                      0.0
# 634                       0.0                      0.0
# 1026                      0.0                      0.0
# 1414                      0.0                      0.0
# 1517                      0.0                      0.0
# 1556                      0.0                      0.0
# 1654                      0.0                      0.0
# 2039                      0.0                      0.0
# 2455                      0.0                      0.0
# 2680                      0.0                      0.0
# 2924                      0.0                      0.0
#
#       obj_true_positive_rate  obj_true_negative_rate  obj_f1  obj_precision  \
# 260                      1.0                     1.0     0.0            1.0
# 262                      1.0                     1.0     0.0            1.0
# 357                      1.0                     1.0     0.0            1.0
# 483                      1.0                     1.0     0.0            1.0
# 634                      1.0                     1.0     0.0            1.0
# 1026                     1.0                     1.0     0.0            1.0
# 1414                     1.0                     1.0     0.0            1.0
# 1517                     1.0                     1.0     0.0            1.0
# 1556                     1.0                     1.0     0.0            1.0
# 1654                     1.0                     1.0     0.0            1.0
# 2039                     1.0                     1.0     0.0            1.0
# 2455                     1.0                     1.0     0.0            1.0
# 2680                     1.0                     1.0     0.0            1.0
# 2924                     1.0                     1.0     0.0            1.0
#
#       obj_auc
# 260       1.0
# 262       1.0
# 357       1.0
# 483       1.0
# 634       1.0
# 1026      1.0
# 1414      1.0
# 1517      1.0
# 1556      1.0
# 1654      1.0
# 2039      1.0
# 2455      1.0
# 2680      1.0
# 2924      1.0
#
# [14 rows x 21 columns]

# %%
df.to_csv('evolution.csv', index=False)

# %%
# create dashboard that allows you to intialize the evolution process

# prompt user to input a data file or choose one hardcoded 

# prompt user to select objectives to consider (check and make sure the objectives make sense w the data)

#
